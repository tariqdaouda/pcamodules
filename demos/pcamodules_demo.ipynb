# %%
import scanpy as sc
import pcamodules.pcamodules as pcam
import importlib

# %% [markdown]
# # Setup

# %%
adata = sc.datasets.pbmc3k_processed()

# %%
sc.pp.pca(adata)
sc.pp.neighbors(adata)
sc.tl.umap(adata)
sc.tl.leiden(adata)

# %%
sc.pl.umap(adata, color=["leiden"])

# %%
importlib.reload(pcam)
finder = pcam.PCAModules(max_iter=100)
finder.fit(adata)
result = finder.select()
# Out:
# /home/tariq/miniconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /home/tariq/miniconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# # Genes for cluster 0

# %%
print("weights:", result.global_max_norm_weights[0][:5])
sc.pl.umap(adata, color=result.genes[0][:5])
# Out:
# weights: [0.3863606928997745, 0.3502959627842348, 0.29587040430524264, 0.2781286189103897, 0.2727257031864128]

# %% [markdown]
# # Genes for cluster 2

# %%
print("weights:", result.global_max_norm_weights[2][:5])
sc.pl.umap(adata, color=result.genes[2][:5])
# Out:
# weights: [0.7591807721988911, 0.7427985702433096, 0.7210865018313046, 0.7000170756245451, 0.6645030524596434]

# %% [markdown]
# # Genes for cluster 1

# %%
print("weights:", result.global_max_norm_weights[1][:5])
sc.pl.umap(adata, color=result.genes[1][:5])
# Out:
# weights: [0.7066794577145883, 0.5642607849355503, 0.5102998740182083, 0.5033826300447155, 0.49784659963937006]

# %% [markdown]
# # Genes for cluster 3

# %%
print("weights:", result.global_max_norm_weights[3][:5])
sc.pl.umap(adata, color=result.genes[3][:5])
# Out:
# weights: [0.6915897864622603, 0.6299703730673295, 0.6259626271070123, 0.5769787199484666, 0.5622612503689314]

# %% [markdown]
# # Cluster 4

# %%
print("weights:", result.global_max_norm_weights[4][:5])
sc.pl.umap(adata, color=result.genes[4][:5])
# Out:
# weights: [0.9477685871486382, 0.6106991130647637, 0.579302914831933, 0.5062278773285502, 0.4828401328913765]

# %% [markdown]
# # Cluster 6

# %%
print("weights:", result.global_max_norm_weights[6][:5])
sc.pl.umap(adata, color=result.genes[6][:5])
# Out:
# weights: [0.2766930775441598, 0.2753633503571173, 0.26220622736053967, 0.2601876367837853, 0.25557756827610617]

# %% [markdown]
# # Cluster 5

# %%
print("weights:", result.global_max_norm_weights[5][:5])
sc.pl.umap(adata, color=result.genes[5][:5])
# Out:
# weights: [1.0, 0.8171618217721037, 0.5306723932029853]
